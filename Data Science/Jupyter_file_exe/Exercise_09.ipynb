# %% [markdown]
# # Coding Exercises (Part 1)

# %% [markdown]
# Now, you will have the opportunity to analyze your own dataset. <br>
# __Follow the instructions__ and insert your code! You are either requested to
# - Complete the Code and __Fill in the gaps__. Gaps are marked with "__---__" and are __placeholders__ for your code fragment.
# - Write Code completely __on your own__

# %% [markdown]
# In some exercises, you will find questions that can only be answered, if your code is correct and returns the right output! The correct answer is provided below your coding cell. There you can check whether your code is correct.

# %% [markdown]
# If you need a hint, check the __Hints Section__ at the end of this Notebook. Exercises and Hints are numerated accordingly.

# %% [markdown]
# If you need some further help or if you want to check your code, you can also watch the __solutions videos__ or check the __solutions notebook__.

# %% [markdown]
# ### Have Fun!

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Visualization with Matplotlib

# %% [markdown]
# ### Exercise 9: Plotting Data with Matplotlib

# %%
# run the cell!
import pandas as pd

# %%
# run the cell!
cars = pd.read_csv("cars.csv")

# %%
# run the cell!
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# 73. __Import__ matplotlib.pyplot (as plt) and set the __style__ to __"seaborn"__! __Fill in the gaps!__

# %%
import matplotlib.pyplot as plt
plt.style.use("seaborn")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\PycharmProjects\Machine learning AI\.venv\Lib\site-packages\matplotlib\style\core.py:137, in use(style)
#     136 try:
# --> 137     style = _rc_params_in_file(style)
#     138 except OSError as err:
#
# File ~\PycharmProjects\Machine learning AI\.venv\Lib\site-packages\matplotlib\__init__.py:879, in _rc_params_in_file(fname, transform, fail_on_error)
#     878 rc_temp = {}
# --> 879 with _open_file_or_url(fname) as fd:
#     880     try:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#
# File ~\PycharmProjects\Machine learning AI\.venv\Lib\site-packages\matplotlib\__init__.py:856, in _open_file_or_url(fname)
#     855 fname = os.path.expanduser(fname)
# --> 856 with open(fname, encoding='utf-8') as f:
#     857     yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: 'seaborn'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.style.use("seaborn")
#
# File ~\PycharmProjects\Machine learning AI\.venv\Lib\site-packages\matplotlib\style\core.py:139, in use(style)
#     137         style = _rc_params_in_file(style)
#     138     except OSError as err:
# --> 139         raise OSError(
#     140             f"{style!r} is not a valid package style, path of style "
#     141             f"file, URL of style file, or library style name (library "
#     142             f"styles are listed in `style.available`)") from err
#     143 filtered = {}
#     144 for k in style:  # don't trigger RcParams.__getitem__('backend')
#
# OSError: 'seaborn' is not a valid package style, path of style file, URL of style file, or library style name (library styles are listed in `style.available`)

# %% [markdown]
# 74. __Create__ the graph below (lineplot for all numerical columns)!

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
cars.plot(
    subplots=True, sharex=False, figsize=(8,8)
)
plt.show()

# %% [markdown]
# 75. __Create__ the graph below (Histogramm for the __"mpg"__ column with 40 bins)!

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
cars.mpg.hist(figsize=(8,6), bins=60)
plt.title("MPG", fontsize=15),
plt.xlabel("mpg", fontsize=13),
plt.ylabel("frequency", fontsize=13)
plt.show()

# %% [markdown]
# 76. __Create__ the graph below (Scatterplot with __horsepower__ and __mpg__)! __Fill in the gaps!__

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
cars.plot(
    kind="scatter", x="horsepower", y="mpg", figsize=(8,7), c="cylinders", marker="x", colormap="viridis"
)
plt.show()

# %% [markdown]
# "# Well Done!

# %% [markdown]
# -----------------------------

# %% [markdown]
# # Hints (Spoiler!)

# %% [markdown]
# 73. plt.style.use()

# %% [markdown]
# 74. plot() method, figure size = (15,15), subplots shall not share x-axis, don´t forget plt.show()

# %% [markdown]
# 75. hist() method, plt.title(), plt.xlabel(), plt.ylabel(), plt.show(), fontsize for title: 15, fontsize for labels: 13, figure size: (12,8)

# %% [markdown]
# 76. "scatter" plot, color of points determined by cylinders column
