# %% [markdown]
# # Converting strings to datetime objects with pd.to_datetime()

# %%
import pandas as pd

# %%
temp = pd.read_csv('../temp.csv')
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  35064 non-null  object
#  1   LA        35062 non-null  float64
#  2   NY        35064 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 821.9+ KB

# %% [markdown]
# ### With the pd.to_datetime() function you can convert strings to datetime objects.

# %%
data = pd.to_datetime(temp.datetime)
data.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 35064 entries, 0 to 35063
# Series name: datetime
# Non-Null Count  Dtype
# --------------  -----
# 35064 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 274.1 KB

# %% [markdown]
# Deleting the old column and setting the new datetime column as the index.

# %%
temp.set_index(pd.to_datetime(temp.datetime)).drop(columns='datetime', axis=1)
# Out:
#                        LA   NY
# datetime
# 2013-01-01 00:00:00  11.7 -1.1
# 2013-01-01 01:00:00  10.7 -1.7
# 2013-01-01 02:00:00   9.9 -2.0
# 2013-01-01 03:00:00   9.3 -2.1
# 2013-01-01 04:00:00   8.8 -2.3
# ...                   ...  ...
# 2016-12-31 19:00:00  13.5  4.6
# 2016-12-31 20:00:00  13.2  5.7
# 2016-12-31 21:00:00  12.8  5.8
# 2016-12-31 22:00:00  12.3  5.7
# 2016-12-31 23:00:00  11.9  5.5
#
# [35064 rows x 2 columns]

# %% [markdown]
# Default format is year-month-day. You can change the format with the format parameter.
# And 00:00:00 is added by default.

# %%
pd.to_datetime('2019-01-01')
# Out:
# Timestamp('2019-01-01 00:00:00')

# %%
pd.to_datetime('2019-01-01 12:32:00')
# Out:
# Timestamp('2019-01-01 12:32:00')

# %%
pd.to_datetime('2019/01/01')
# Out:
# Timestamp('2019-01-01 00:00:00')

# %%
pd.to_datetime('2019 01 03')
# Out:
# Timestamp('2019-01-03 00:00:00')

# %%
pd.to_datetime('2019 May 03')
# Out:
# Timestamp('2019-05-03 00:00:00')

# %% [markdown]
# ### You can also specify the format of the string.
# ### %Y: year, %m: month, %d: day,
# ### %H: hour, %M: minute, %S: second

# %%
pd.to_datetime('01-03-2019', format='%d-%m-%Y')
# Out:
# Timestamp('2019-03-01 00:00:00')

# %%
pd.to_datetime(['01-03-2019', '02-03-2019'], format='%d-%m-%Y')
# Out:
# DatetimeIndex(['2019-03-01', '2019-03-02'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ### If the string is not in the specified format, it will raise an error. With the errors parameter you can ignore the error.

# %%
pd.to_datetime(['01-03-2019', '02-03-2019', 'Elephant'], format='%d-%m-%Y', errors='coerce')
# Out:
# DatetimeIndex(['2019-03-01', '2019-03-02', 'NaT'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# # Vizualization Time Series Data
#
# Use plot method we have automatically x-axis and y-axis labels.

# %%
from matplotlib.pyplot import plot

temp.set_index('datetime')

temp.plot(figsize=(15, 5))
plot.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 6
#       3 temp.set_index('datetime')
#       5 temp.plot(figsize=(15, 5))
# ----> 6 plot.show()
#
# AttributeError: 'function' object has no attribute 'show'

# %%
temp.plot(figsize=(15, 5), subplots=True, layout=(1, 2), sharey=True)
plot.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 2
#       1 temp.plot(figsize=(15, 5), subplots=True, layout=(1, 2), sharey=True)
# ----> 2 plot.show()
#
# AttributeError: 'function' object has no attribute 'show'
